# %%
import ast
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
df = pd.read_pickle('df-pkl')
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA_PT = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'Portugal')].copy()

# Drop NaN values from the 'salary_year_avg' column for accurate visualization
df_DA_PT = df_DA_PT.dropna(subset=['salary_year_avg'])

df_DA_PT_exploded = df_DA_PT.explode('job_skills')

df_DA_PT_exploded[['salary_year_avg', 'job_skills']].head(5)
# Out:
#        salary_year_avg  job_skills
# 1555          111175.0  databricks
# 1555          111175.0       spark
# 67571         111175.0         sql
# 67571         111175.0    bigquery
# 67571         111175.0      looker

# %%
# Calculate percent of job postings that have each skill
df_DA_skills = df_DA_PT_exploded.groupby('job_skills')['salary_year_avg'].agg(['count', 'median']).sort_values(by='count', ascending=False)

df_DA_skills = df_DA_skills.rename(columns={'count': 'skill_count', 'median': 'median_salary'})

DA_job_count = len(df_DA_PT)  # Find count of Data Analyst jobs in PT with salary info

df_DA_skills['skill_percent'] = df_DA_skills['skill_count'] / DA_job_count * 100

df_DA_skills = df_DA_skills[df_DA_skills['skill_count'] > 0]

df_DA_skills
# Out:
#                skill_count  median_salary  skill_percent
# job_skills
# sql                     15       111175.0      40.540541
# python                  13        89204.0      35.135135
# tableau                  8       111175.0      21.621622
# excel                    8        76875.0      21.621622
# looker                   7       111175.0      18.918919
# power bi                 5        89100.0      13.513514
# r                        5       111175.0      13.513514
# spark                    4       100137.5      10.810811
# bigquery                 3       118190.0       8.108108
# go                       3        53014.0       8.108108
# sas                      2        72900.0       5.405405
# sap                      2       127050.0       5.405405
# github                   2        81052.0       5.405405
# hadoop                   2        65200.0       5.405405
# sql server               2       141595.0       5.405405
# databricks               2       138087.5       5.405405
# scikit-learn             1        72900.0       2.702703
# spss                     1        72900.0       2.702703
# vba                      1       111175.0       2.702703
# qlik                     1        89204.0       2.702703
# azure                    1       165000.0       2.702703
# powerpoint               1        51014.0       2.702703
# pandas                   1        72900.0       2.702703
# jupyter                  1        72900.0       2.702703
# javascript               1        80850.0       2.702703
# html                     1        80850.0       2.702703
# git                      1       165000.0       2.702703
# gdpr                     1       165000.0       2.702703
# elasticsearch            1        72900.0       2.702703
# dax                      1       111175.0       2.702703
# cognos                   1        51014.0       2.702703
# c#                       1        57500.0       2.702703
# word                     1        80850.0       2.702703

# %%
skill_limit = 5

df_DA_skills_high_demand = df_DA_skills[df_DA_skills['skill_percent'] > skill_limit]

# %%
# !pip install adjustText
from adjustText import adjust_text

plt.scatter(df_DA_skills_high_demand['skill_percent'], df_DA_skills_high_demand['median_salary'])
plt.xlabel('Percent of Data Analyst Jobs')
plt.ylabel('Median Salary')  # Assuming this is the label you want for y-axis
plt.title('Most Optimal Skills for Data Analysts in PT')

# Get current axes, set limits, and format axes
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'€{int(y/1000)}K'))

# Add labels to points and collect them in a list
texts = []
for i, txt in enumerate(df_DA_skills_high_demand.index):
    texts.append(plt.text(df_DA_skills_high_demand['skill_percent'].iloc[i], df_DA_skills_high_demand['median_salary'].iloc[i], " " + txt))

# Adjust text to avoid overlap and add arrows
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))

plt.show()
# Out:
# Requirement already satisfied: adjustText in /opt/anaconda3/envs/python_course/lib/python3.12/site-packages (1.3.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/python_course/lib/python3.12/site-packages (from adjustText) (1.26.4)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/python_course/lib/python3.12/site-packages (from adjustText) (3.9.2)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/python_course/lib/python3.12/site-packages (from adjustText) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/python_course/lib/python3.12/site-packages (from matplotlib->adjustText) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/python_course/lib/python3.12/site-packages (from matplotlib->adjustText) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/python_course/lib/python3.12/site-packages (from matplotlib->adjustText) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/python_course/lib/python3.12/site-packages (from matplotlib->adjustText) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/python_course/lib/python3.12/site-packages (from matplotlib->adjustText) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/python_course/lib/python3.12/site-packages (from matplotlib->adjustText) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/python_course/lib/python3.12/site-packages (from matplotlib->adjustText) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/python_course/lib/python3.12/site-packages (from matplotlib->adjustText) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/python_course/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->adjustText) (1.16.0)

# %%
df_technology = df['job_type_skills'].copy()

# remove duplicates
df_technology = df_technology.drop_duplicates()

# remove NaN values
df_technology = df_technology.dropna()

# combine all dictionaries into one
technology_dict = {}
for row in df_technology:
    row_dict = ast.literal_eval(row)  # convert string to dictionary
    for key, value in row_dict.items():
        if key in technology_dict:  # if key already exists in technology_dict, add value to existing value
            technology_dict[key] += value
        else:                       # if key does not exist in technology_dict, add key and value
            technology_dict[key] = value

# remove duplicates by converting values to set then back to list
for key, value in technology_dict.items():
    technology_dict[key] = list(set(value))

technology_dict
# Out:
# {'analyst_tools': ['datarobot',
#   'word',
#   'microstrategy',
#   'ssis',
#   'outlook',
#   'dax',
#   'ssrs',
#   'spreadsheet',
#   'sharepoint',
#   'power bi',
#   'spss',
#   'tableau',
#   'powerbi',
#   'ms access',
#   'excel',
#   'sas',
#   'sheets',
#   'esquisse',
#   'qlik',
#   'cognos',
#   'alteryx',
#   'splunk',
#   'nuix',
#   'msaccess',
#   'visio',
#   'looker',
#   'powerpoint',
#   'sap'],
#  'programming': ['golang',
#   'crystal',
#   'bash',
#   'javascript',
#   'solidity',
#   'clojure',
#   'elixir',
#   'mongo',
#   'scala',
#   'html',
#   'f#',
#   'nosql',
#   'rust',
#   'julia',
#   'apl',
#   'visual basic',
#   'mongodb',
#   'vba',
#   'perl',
#   'swift',
#   'css',
#   'lua',
#   'no-sql',
#   'go',
#   'sass',
#   'groovy',
#   'assembly',
#   'typescript',
#   'ruby',
#   't-sql',
#   'ocaml',
#   'shell',
#   'sas',
#   'visualbasic',
#   'dart',
#   'delphi',
#   'c#',
#   'matlab',
#   'python',
#   'vb.net',
#   'java',
#   'pascal',
#   'php',
#   'sql',
#   'haskell',
#   'lisp',
#   'cobol',
#   'objective-c',
#   'kotlin',
#   'powershell',
#   'r',
#   'fortran',
#   'erlang',
#   'c++',
#   'c'],
#  'cloud': ['linode',
#   'azure',
#   'bigquery',
#   'heroku',
#   'ibm cloud',
#   'databricks',
#   'gcp',
#   'digitalocean',
#   'vmware',
#   'ovh',
#   'oracle',
#   'aurora',
#   'snowflake',
#   'aws',
#   'colocation',
#   'firebase',
#   'openstack',
#   'watson',
#   'redshift'],
#  'libraries': ['jupyter',
#   'ionic',
#   'seaborn',
#   'selenium',
#   'ggplot2',
#   'tensorflow',
#   'hadoop',
#   'theano',
#   'dlib',
#   'pytorch',
#   'mxnet',
#   'capacitor',
#   'tidyr',
#   'airflow',
#   'keras',
#   'huggingface',
#   'flutter',
#   'numpy',
#   'mlr',
#   'react',
#   'spring',
#   'mlpack',
#   'electron',
#   'cordova',
#   'pyspark',
#   'spark',
#   'pandas',
#   'rshiny',
#   'dplyr',
#   'kafka',
#   'chainer',
#   'graphql',
#   'gdpr',
#   'opencv',
#   'tidyverse',
#   'plotly',
#   'hugging face',
#   'qt',
#   'matplotlib',
#   'shogun',
#   'xamarin',
#   'gtx',
#   'scikit-learn',
#   'nltk'],
#  'other': ['bitbucket',
#   'git',
#   'svn',
#   'chef',
#   'pulumi',
#   'homebrew',
#   'flow',
#   'terminal',
#   'terraform',
#   'atlassian',
#   'gitlab',
#   'yarn',
#   'unreal',
#   'kubernetes',
#   'jenkins',
#   'ansible',
#   'codecommit',
#   'github',
#   'docker',
#   'puppet',
#   'npm',
#   'unity'],
#  'databases': ['couchbase',
#   'mariadb',
#   'neo4j',
#   'firebase',
#   'sqlite',
#   'mongodb',
#   'sql server',
#   'firestore',
#   'couchdb',
#   'redis',
#   'postgresql',
#   'sqlserver',
#   'dynamodb',
#   'db2',
#   'mysql',
#   'elasticsearch',
#   'cassandra'],
#  'os': ['unix',
#   'windows',
#   'macos',
#   'arch',
#   'ubuntu',
#   'suse',
#   'redhat',
#   'fedora',
#   'wsl',
#   'linux',
#   'debian',
#   'centos',
#   'kali'],
#  'async': ['monday.com',
#   'notion',
#   'trello',
#   'smartsheet',
#   'wimi',
#   'clickup',
#   'airtable',
#   'planner',
#   'workfront',
#   'microsoft lists',
#   'dingtalk',
#   'jira',
#   'asana',
#   'wrike',
#   'confluence'],
#  'webframeworks': ['phoenix',
#   'jquery',
#   'blazor',
#   'play framework',
#   'deno',
#   'asp.netcore',
#   'express',
#   'asp.net',
#   'django',
#   'fastapi',
#   'rubyon rails',
#   'ruby',
#   'node',
#   'angular',
#   'fastify',
#   'drupal',
#   'symfony',
#   'node.js',
#   'react.js',
#   'ruby on rails',
#   'vue.js',
#   'nuxt.js',
#   'gatsby',
#   'flask',
#   'vue',
#   'asp.net core',
#   'laravel',
#   'next.js',
#   'angular.js',
#   'svelte',
#   'ember.js'],
#  'sync': ['twilio',
#   'zoom',
#   'slack',
#   'wire',
#   'rocketchat',
#   'microsoft teams',
#   'unify',
#   'symphony',
#   'webex',
#   'google chat',
#   'mattermost',
#   'ringcentral']}

# %%
# turn dictionary into dataframe
df_technology = pd.DataFrame(list(technology_dict.items()), columns=['technology', 'skills'])

df_technology = df_technology.explode('skills')

df_technology
# Out:
#        technology         skills
# 0   analyst_tools      datarobot
# 0   analyst_tools           word
# 0   analyst_tools  microstrategy
# 0   analyst_tools           ssis
# 0   analyst_tools        outlook
# ..            ...            ...
# 9            sync       symphony
# 9            sync          webex
# 9            sync    google chat
# 9            sync     mattermost
# 9            sync    ringcentral
#
# [256 rows x 2 columns]

# %%
# merge df_DA_skills and df_technology
df_DA_skills_tech = df_DA_skills.merge(df_technology, left_on='job_skills', right_on='skills')

df_DA_skills_tech
# Out:
#     skill_count  median_salary  skill_percent     technology         skills
# 0            15       111175.0      40.540541    programming            sql
# 1            13        89204.0      35.135135    programming         python
# 2             8       111175.0      21.621622  analyst_tools        tableau
# 3             8        76875.0      21.621622  analyst_tools          excel
# 4             7       111175.0      18.918919  analyst_tools         looker
# 5             5        89100.0      13.513514  analyst_tools       power bi
# 6             5       111175.0      13.513514    programming              r
# 7             4       100137.5      10.810811      libraries          spark
# 8             3       118190.0       8.108108          cloud       bigquery
# 9             3        53014.0       8.108108    programming             go
# 10            2        72900.0       5.405405  analyst_tools            sas
# 11            2        72900.0       5.405405    programming            sas
# 12            2       127050.0       5.405405  analyst_tools            sap
# 13            2        81052.0       5.405405          other         github
# 14            2        65200.0       5.405405      libraries         hadoop
# 15            2       141595.0       5.405405      databases     sql server
# 16            2       138087.5       5.405405          cloud     databricks
# 17            1        72900.0       2.702703      libraries   scikit-learn
# 18            1        72900.0       2.702703  analyst_tools           spss
# 19            1       111175.0       2.702703    programming            vba
# 20            1        89204.0       2.702703  analyst_tools           qlik
# 21            1       165000.0       2.702703          cloud          azure
# 22            1        51014.0       2.702703  analyst_tools     powerpoint
# 23            1        72900.0       2.702703      libraries         pandas
# 24            1        72900.0       2.702703      libraries        jupyter
# 25            1        80850.0       2.702703    programming     javascript
# 26            1        80850.0       2.702703    programming           html
# 27            1       165000.0       2.702703          other            git
# 28            1       165000.0       2.702703      libraries           gdpr
# 29            1        72900.0       2.702703      databases  elasticsearch
# 30            1       111175.0       2.702703  analyst_tools            dax
# 31            1        51014.0       2.702703  analyst_tools         cognos
# 32            1        57500.0       2.702703    programming             c#
# 33            1        80850.0       2.702703  analyst_tools           word

# %%
df_DA_skills_tech_high_demand = df_DA_skills_tech[df_DA_skills_tech['skill_percent'] > skill_limit]

# %%
sns.scatterplot(
    data=df_DA_skills_tech_high_demand,
    x='skill_percent',
    y='median_salary',
    hue='technology'
)

sns.despine()
sns.set_theme(style='ticks')

# Prepare texts for adjustText
texts = []
for i, txt in enumerate(df_DA_skills_high_demand.index):
    texts.append(plt.text(df_DA_skills_high_demand['skill_percent'].iloc[i], df_DA_skills_high_demand['median_salary'].iloc[i], txt))

# Adjust text to avoid overlap
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))

# Set axis labels, title, and legend
plt.xlabel('Percent of Data Analyst Jobs')
plt.ylabel('Median Yearly Salary')
plt.title('Most Optimal Skills for Data Analysts in the US')
plt.legend(title='Technology')

from matplotlib.ticker import PercentFormatter
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))
ax.xaxis.set_major_formatter(PercentFormatter(decimals=0))

# Adjust layout and display plot 
plt.tight_layout()
plt.show()
